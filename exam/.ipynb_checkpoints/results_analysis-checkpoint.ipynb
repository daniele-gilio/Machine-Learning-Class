# %%
import gzip
from collections import Counter
import dictionary_functions as df
import pvml
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

####### Read Files ##########
f=gzip.open("train.txt.gz", "rt")
klass=[]
publisher=[]
title=[]
for line in f:
    k, p, t = line.split("|")
    klass.append(k)
    publisher.append(p)
    title.append(t)

####### Encode Classes and Publishers #########
pub=sorted(list(Counter(publisher).keys())) #Get the list of unique publishers
kla=sorted(list(Counter(klass).keys())) #Get the list of unique classes

pub_enc=[]
klass_enc=[]
for p in publisher:
    pub_enc.append(pub.index(p)) #use the publisher index in pub to encode publishers
for k in klass:
    klass_enc.append(kla.index(k)) #use the class index in kla to encode classes

y_train=np.array(klass_enc)
t_pub_enc=pub_enc
t_title=title

######## Repeat for Validation and Test Sets #########
####### Read Files ##########
f=gzip.open("validation.txt.gz", "rt")
klass=[]
publisher=[]
title=[]
for line in f:
    k, p, t = line.split("|")
    klass.append(k)
    publisher.append(p)
    title.append(t)

####### Encode Classes and Publishers #########
pub=sorted(list(Counter(publisher).keys())) #Get the list of unique publishers
kla=sorted(list(Counter(klass).keys())) #Get the list of unique classes
pub_enc=[]
klass_enc=[]
for p in publisher:
    pub_enc.append(pub.index(p)) #use the publisher index in pub to encode publishers
for k in klass:
    klass_enc.append(kla.index(k)) #use the class index in kla to encode classes

y_val=np.array(klass_enc)
val_pub_enc=pub_enc
val_title=title

####### Read Files ##########
f=gzip.open("test.txt.gz", "rt")
klass=[]
publisher=[]
title=[]
for line in f:
    k, p, t = line.split("|")
    klass.append(k)
    publisher.append(p)
    title.append(t)

####### Encode Classes and Publishers #########
pub=sorted(list(Counter(publisher).keys())) #Get the list of unique publishers
kla=sorted(list(Counter(klass).keys())) #Get the list of unique classes

pub_enc=[]
klass_enc=[]
for p in publisher:
    pub_enc.append(pub.index(p)) #use the publisher index in pub to encode publishers
for k in klass:
    klass_enc.append(kla.index(k)) #use the class index in kla to encode classes

y_test=np.array(klass_enc)
test_pub_enc=pub_enc
test_title=title



######## Create Dictionary #########
size=8000
stem=True
ic=True
dic=df.build_dict(t_title, size, True, stemming=stem, ignore_common=ic)

######## Training Set ######
######## Create BoW ########
bow=df.build_bow(t_title, False, "train_bow", size, stemming=stem)
t_pub_enc=np.array(t_pub_enc)


######## Consolidate Features ########
x_train=np.zeros((len(t_pub_enc), size+1))
#bow=pvml.maxabs_normalization(bow)
for i in range(len(t_pub_enc)):
    x_train[i][:-1]=bow[i]
    x_train[i][-1]=t_pub_enc[i]

######## Validation Set ####
######## Create BoW ########
bow=df.build_bow(val_title, False, "val_bow", size, stemming=stem)
val_pub_enc=np.array(val_pub_enc)


######## Consolidate Features ########
x_val=np.zeros((len(val_pub_enc), size+1))
#bow=pvml.maxabs_normalization(bow)
for i in range(len(val_pub_enc)):
    x_val[i][:-1]=bow[i]
    x_val[i][-1]=val_pub_enc[i]

######## Test Set ##########
######## Create BoW ########
bow=df.build_bow(test_title, False, "test_bow", size, stemming=stem)
test_pub_enc=np.array(test_pub_enc)


######## Consolidate Features ########
x_test=np.zeros((len(test_pub_enc), size+1))
#bow=pvml.maxabs_normalization(bow)

for i in range(len(test_pub_enc)):
    x_test[i][:-1]=bow[i]
    x_test[i][-1]=test_pub_enc[i]

# %%
######## Bayes #########
data=np.load("bayes_"+str(size)+".npz", allow_pickle=True)
w=data["weights"]
b=data["biases"]
labels, scores = pvml.multinomial_naive_bayes_inference(x_train, w, b)
acc=(labels==y_train).mean()*100
print("Training Accuracy: ", acc)

labels, scores = pvml.multinomial_naive_bayes_inference(x_val, w, b)
acc=(labels==y_val).mean()*100
print("Validation Accuracy: ", acc)

labels, scores = pvml.multinomial_naive_bayes_inference(x_test, w, b)
acc=(labels==y_test).mean()*100
print("Test Accuracy: ", acc)

b_acc=acc

w_n=5 #<- Number of Wrong Classifications to show
wrong=np.asarray(labels!=y_test)

w_scores=[]
for i in range(len(wrong)):
    if wrong[i]==True:
        w_scores.append(scores[i][labels[i]])
    else:
        w_scores.append(-5000)

w_scores=np.array(w_scores)
w_index=w_scores.argsort()

print()
print("Wrongest Classifications")
print()

for i in range(1,w_n+1):
    print("Title:", test_title[w_index[-i]])
    print("Correct Class:", kla[y_test[w_index[-i]]], "Predicted Class:", kla[labels[w_index[-i]]])
    print()

conf_mat=np.zeros((4,4))
for i in range(len(y_test)):
    conf_mat[int(y_test[i])][int(labels[i])]+=1
for i in range(4):
    conf_mat[i,:]/=conf_mat[i,:].sum()

sn.heatmap(conf_mat, annot=True, cmap="coolwarm")
plt.title("Multinomial Naive Bayes Confusion Matrix")
plt.xticks(np.linspace(0.5, 3.5, 4),kla)
plt.yticks(np.linspace(0.5, 3.5, 4),kla, rotation="horizontal")
plt.show()

bayes_acc=[82.3, 88.3, 90.4, 90.3, 90.0] #no-norm
#2500
#88.3 no-norm
#85.7 maxabs
#87.9 ignore_common
#88.0 stemming
#88.9 ignore_common+stemming
# Out:
# Training Accuracy:  94.38
# Validation Accuracy:  89.2
# Test Accuracy:  91.10000000000001
#
# Wrongest Classifications
#
# Title: Rebased GDP and UN-Rebased Realities
#
# Correct Class: business Predicted Class: science
#
# Title: How Much Alcohol is in Your Cocktail?
#
# Correct Class: health Predicted Class: business
#
# Title: Condom use drops among US teens
#
# Correct Class: health Predicted Class: business
#
# Title: Behind Every Easter Is a Crucifixion
#
# Correct Class: entertainment Predicted Class: science
#
# Title: Starbucks may sway the wireless-charging wars
#
# Correct Class: science Predicted Class: entertainment

# %%
######## LogReg ############
data=np.load("logreg_"+str(size)+".npz", allow_pickle=True)
w=data["weights"]
b=data["biases"]
scores=pvml.multinomial_logreg_inference(x_train, w, b)
labels=np.argmax(scores, axis=1)
acc=np.array(labels==y_train).mean()*100
print("Training Accuracy: ", acc)

scores=pvml.multinomial_logreg_inference(x_val, w, b)
labels=np.argmax(scores, axis=1)
acc=np.array(labels==y_val).mean()*100
print("Validation Accuracy: ", acc)

scores=pvml.multinomial_logreg_inference(x_test, w, b)
labels=np.argmax(scores, axis=1)
acc=np.array(labels==y_test).mean()*100
print("Test Accuracy: ", acc)

l_acc=acc

w_n=5 #<- Number of Wrong Classifications to show
wrong=np.asarray((labels!=y_test))

w_scores=[]
for i in range(len(wrong)):
    if wrong[i]==True:
        w_scores.append(scores[i][labels[i]])
    else:
        w_scores.append(-1)

w_scores=np.array(w_scores)
w_index=w_scores.argsort()


print()
print("Wrongest Classifications")
print()
for i in range(1,w_n+1):
    print("Title:", test_title[w_index[-i]])
    print("Correct Class:", kla[y_test[w_index[-i]]], "Predicted Class:", kla[labels[w_index[-i]]])
    print()

conf_mat=np.zeros((4,4))
for i in range(len(y_test)):
    conf_mat[int(y_test[i])][int(labels[i])]+=1
for i in range(4):
    conf_mat[i,:]/=conf_mat[i,:].sum()

sn.heatmap(conf_mat, annot=True, cmap="coolwarm")
plt.title("Multinomial LogReg Confusion Matrix")
plt.xticks(np.linspace(0.5, 3.5, 4),kla)
plt.yticks(np.linspace(0.5, 3.5, 4),kla, rotation="horizontal")
plt.show()
logreg_acc=[72.8, 75.1, 75.6, 75.5, 75.6]
#2500
#75.1 no-norm
#72.6 maxabs
#74.4 ignore_common
#76.8 stemming
#76.7 ignore_common+stemming
# Out:
# Training Accuracy:  76.92999999999999
# Validation Accuracy:  77.4
# Test Accuracy:  76.7
#
# Wrongest Classifications
#
# Title: UPDATE 1-Twitter buys social data provider Gnip, stock soars
#
# Correct Class: science Predicted Class: business
#
# Title: Google ahead of Apple as most valuable brand
#
# Correct Class: business Predicted Class: science
#
# Title: Sector Update: Healthcare Shares Mixed Pre-Market; Pfizer Sinks 3% on Results  ...
#
# Correct Class: health Predicted Class: business
#
# Title: UPDATE 4-Yahoo to keep more of Alibaba, share half of IPO proceeds
#
# Correct Class: science Predicted Class: business
#
# Title: Google, Barnes & Noble partner to challenge Amazon on book delivery service
#
# Correct Class: business Predicted Class: science

# %%
########### Normalize Bow with MaxAbs for SLP and MLP (as in training) ############
for i in range(len(t_pub_enc)):
    x_train[i][:-1]=pvml.maxabs_normalization(x_train[i][:-1])
for i in range(len(val_pub_enc)):
    x_val[i][:-1]=pvml.maxabs_normalization(x_val[i][:-1])
for i in range(len(test_pub_enc)):
    x_test[i][:-1]=pvml.maxabs_normalization(x_test[i][:-1])

########## SLP ##########
snn=pvml.MLP.load("snn_"+str(size)+".npz")
train_labels=snn.inference(x_train)[0]
train_acc=(train_labels==y_train).mean()*100
print("Final Training Accuracy: ", train_acc)
val_labels=snn.inference(x_val)[0]
val_acc=(val_labels==y_val).mean()*100
print("Final Validation Accuracy: ", val_acc)
test_labels, test_scores=snn.inference(x_test)
test_acc=(test_labels==y_test).mean()*100
print("Test Accuracy: ", test_acc)

s_acc=test_acc
w_n=5 #<- Number of Wrong Classifications to show
wrong=np.asarray((test_labels!=y_test))

w_scores=[]
for i in range(len(wrong)):
    if wrong[i]==True:
        w_scores.append(test_scores[i][test_labels[i]])
    else:
        w_scores.append(-1)

w_scores=np.array(w_scores)
w_index=w_scores.argsort()


print()
print("Wrongest Classifications")
print()
for i in range(1,w_n+1):
    print("Title:", test_title[w_index[-i]])
    print("Correct Class:", kla[y_test[w_index[-i]]], "Predicted Class:", kla[test_labels[w_index[-i]]])
    print()

conf_mat=np.zeros((4,4))
for i in range(len(y_test)):
    conf_mat[int(y_test[i])][int(test_labels[i])]+=1
for i in range(4):
    conf_mat[i,:]/=conf_mat[i,:].sum()

sn.heatmap(conf_mat, annot=True, cmap="coolwarm")
plt.title("SLP Confusion Matrix")
plt.xticks(np.linspace(0.5, 3.5, 4),kla)
plt.yticks(np.linspace(0.5, 3.5, 4),kla, rotation="horizontal")
plt.show()

slp_acc=[83.2, 87.6, 89.6, 89.9, 90.2]
#2500
#87.6 no-norm
#87.9 maxabs
#88.2 ignore_common
#89.4 Stemming
#89.4 ignore_common+stemming
# Out:
# Final Training Accuracy:  98.82
# Final Validation Accuracy:  90.5
# Test Accuracy:  91.5
#
# Wrongest Classifications
#
# Title: 36 People Hospitalized at Avicii Concert in Boston after Suffering Medical Issues
#
# Correct Class: entertainment Predicted Class: health
#
# Title: Sector Update: Healthcare Shares Mixed Pre-Market; Pfizer Sinks 3% on Results  ...
#
# Correct Class: health Predicted Class: business
#
# Title: UPDATE 1-Twitter buys social data provider Gnip, stock soars
#
# Correct Class: science Predicted Class: business
#
# Title: Transformers: Age of Extinction Brings Giant Robot Dinosaurs and Even Bigger  ...
#
# Correct Class: entertainment Predicted Class: science
#
# Title: American Apparel boss fired over sex slave claims accuses board of 'hateful  ...
#
# Correct Class: business Predicted Class: entertainment

# %%
######### 
plt.plot(np.linspace(1000, 10000, 5), bayes_acc, label="Bayes", marker=".")
plt.plot(np.linspace(1000, 10000, 5), logreg_acc, label="LogReg", marker=".")
plt.plot(np.linspace(1000, 10000, 5), slp_acc, label="SLP", marker=".")
plt.title("Accuracy Vs. Dictionary Size")
plt.xlabel("Dictionary Size")
plt.ylabel("Accuracy [%]")
plt.grid()
plt.legend()
plt.show()

x=[8,16,32,64,128,256,512]
y=[88.1,91.2,90.5,90.7,90.3,91.1,91]
plt.plot(x,y, marker=".")
plt.semilogx()
plt.grid()
plt.title("Accuracy Vs. Hidden Layer Size")
plt.xlabel("Layer Width")
plt.ylabel("Test Accuracy [%]")
plt.show()

# %%
########## MLP ##########
dnn=pvml.MLP.load("dnn_"+str(size)+".npz")
train_labels=dnn.inference(x_train)[0]
train_acc=(train_labels==y_train).mean()*100
print("Final Training Accuracy: ", train_acc)
val_labels=dnn.inference(x_val)[0]
val_acc=(val_labels==y_val).mean()*100
print("Final Validation Accuracy: ", val_acc)
test_labels, test_scores=dnn.inference(x_test)
test_acc=(test_labels==y_test).mean()*100
print("Test Accuracy: ", test_acc)
mlp_acc=test_acc

w_n=5 #<- Number of Wrong Classifications to show
wrong=np.asarray((test_labels!=y_test))

w_scores=[]
for i in range(len(wrong)):
    if wrong[i]==True:
        w_scores.append(test_scores[i][test_labels[i]])
    else:
        w_scores.append(-1)

w_scores=np.array(w_scores)
w_index=w_scores.argsort()


print()
print("Wrongest Classifications")
print()
for i in range(1,w_n+1):
    print("Title:", test_title[w_index[-i]])
    print("Correct Class:", kla[y_test[w_index[-i]]], "Predicted Class:", kla[test_labels[w_index[-i]]])
    print()

conf_mat=np.zeros((4,4))
for i in range(len(y_test)):
    conf_mat[int(y_test[i])][int(test_labels[i])]+=1
for i in range(4):
    conf_mat[i,:]/=conf_mat[i,:].sum()

sn.heatmap(conf_mat, annot=True, cmap="coolwarm")
plt.title("MLP Confusion Matrix")
plt.xticks(np.linspace(0.5, 3.5, 4),kla)
plt.yticks(np.linspace(0.5, 3.5, 4),kla, rotation="horizontal")
plt.show()
#[size+1, 256, 64, 16, 4] (ic+stem)(2500) 89.7
#[size+1, 8, 8, 4] // // 84.89
#[size+1, 64, 8, 4] // // 89.6
#[size+1, 32, 8, 4] // // 87.2
#[size+1, 512, 64, 8, 4] // // 87.9
#[size+1, 256, 64, 8, 4] // // 87.1
#[size+1, 512, 4] // // 91.0
#[size+1, 256, 4] // // 91.1
#[size+1, 128, 4] // // 90.3
#[size+1, 64, 4] // // 90.7
#[size+1, 32, 4] // // 90.5
#[size+1, 16, 4] // // 91.2
#[size+1, 8, 4] // // 88.1
# Out:
# Final Training Accuracy:  99.1
# Final Validation Accuracy:  90.4
# Test Accuracy:  92.9
#
# Wrongest Classifications
#
# Title: Sector Update: Healthcare Shares Mixed Pre-Market; Pfizer Sinks 3% on Results  ...
#
# Correct Class: health Predicted Class: business
#
# Title: UPDATE 1-Twitter buys social data provider Gnip, stock soars
#
# Correct Class: science Predicted Class: business
#
# Title: 36 People Hospitalized at Avicii Concert in Boston after Suffering Medical Issues
#
# Correct Class: entertainment Predicted Class: health
#
# Title: Transformers: Age of Extinction Brings Giant Robot Dinosaurs and Even Bigger  ...
#
# Correct Class: entertainment Predicted Class: science
#
# Title: Behind Alibaba IPO is an unlikely China success story
#
# Correct Class: science Predicted Class: business

# %%
########### Accuracy vs. Training Time #############
bayes_time=2.774
logreg_time=912.641
slp_time=338.017
mlp_time=646.121
_time=[bayes_time, logreg_time, slp_time, mlp_time]
_acc=[b_acc, l_acc, s_acc, mlp_acc]
sz=[100, 10000, 1500, 350] #number of epochs to train the models, the bayes number is arbitrary but smaller than
                            #all the others since it does not use Gradient Descent
names=["Bayes", "LogReg", "SLP", "MLP"]
plt.rcParams['figure.figsize'] = 16,9

for i in range(4):
    plt.scatter(_time[i], _acc[i], s=sz[i], label=names[i])
    
plt.legend(markerscale=0.18)
plt.title("Accuracy Vs. Training Time")
plt.xlabel("Time [s]")
plt.ylabel("Accuracy [%]")
plt.grid()
plt.show()

# %%
######## Most Polarizing Words #########
dic=df.get_dict(size)
for j in range(19):
    diag=np.zeros((size+1,size+1))
    for i in range(size+1):
        diag[i][i]=1
        diag[i][-1]=j
    labels, scores=dnn.inference(diag)
    h=scores[0][labels[0]]
    l=scores[0][labels[0]]
    h_ind=0
    l_ind=0
    print("\033[1m" + "Publisher: ", pub[j], '\033[0m')
    for t in range(4):
        for k in range(1,size+1):
            if scores[k][labels[k]]>h and labels[k]==t:
                h=scores[k][labels[k]]
                h_ind=k
            elif scores[k][labels[k]]<l and labels[k]==t:
                l=scores[k][labels[k]]
                l_ind=k
        print(kla[t])
        print("Most Influencial Word:", df.get_word(dic, h_ind), ", Score:", h)
        print("Least Influencial Word:", df.get_word(dic, l_ind), ", Score:", l)
        print()
# Out:
# Publisher:  AllAfrica.com
# business
# Most Influencial Word: bank , Score: 0.9929984151651264
# Least Influencial Word: halfwai , Score: 0.2790390158475014
#
# entertainment
# Most Influencial Word: bank , Score: 0.9929984151651264
# Least Influencial Word: mandela , Score: 0.26929759003105314
#
# health
# Most Influencial Word: ebola , Score: 0.9998825234229759
# Least Influencial Word: mandela , Score: 0.26929759003105314
#
# science
# Most Influencial Word: ebola , Score: 0.9998825234229759
# Least Influencial Word: mandela , Score: 0.26929759003105314
#
# Publisher:  CBS Local
# business
# Most Influencial Word: tax , Score: 0.99835209805946
# Least Influencial Word: termin , Score: 0.2726119866106821
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9983870846938409
# Least Influencial Word: expect , Score: 0.26792148929081494
#
# health
# Most Influencial Word: ebola , Score: 0.9993392985989522
# Least Influencial Word: postiv , Score: 0.2587284134224219
#
# science
# Most Influencial Word: googl , Score: 0.9997663589173177
# Least Influencial Word: postiv , Score: 0.2587284134224219
#
# Publisher:  CNET
# business
# Most Influencial Word: tax , Score: 0.9962302769666395
# Least Influencial Word: employe , Score: 0.3311341392496989
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9998666836648249
# Least Influencial Word: employe , Score: 0.3311341392496989
#
# health
# Most Influencial Word: kardashian , Score: 0.9998666836648249
# Least Influencial Word: employe , Score: 0.3311341392496989
#
# science
# Most Influencial Word: googl , Score: 0.9998955085237764
# Least Influencial Word: employe , Score: 0.3311341392496989
#
# Publisher:  Contactmusic.com
# business
# Most Influencial Word: tax , Score: 0.9883802095551774
# Least Influencial Word: ocean , Score: 0.33939319621701103
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.999974374003959
# Least Influencial Word: zoo , Score: 0.33837848895235884
#
# health
# Most Influencial Word: kardashian , Score: 0.999974374003959
# Least Influencial Word: zoo , Score: 0.33837848895235884
#
# science
# Most Influencial Word: kardashian , Score: 0.999974374003959
# Least Influencial Word: zoo , Score: 0.33837848895235884
#
# Publisher:  Daily Mail
# business
# Most Influencial Word: tax , Score: 0.9897630310922105
# Least Influencial Word: retail , Score: 0.4004599002922461
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999889930023003
# Least Influencial Word: dna , Score: 0.3475982746535392
#
# health
# Most Influencial Word: kardashian , Score: 0.9999889930023003
# Least Influencial Word: dna , Score: 0.3475982746535392
#
# science
# Most Influencial Word: kardashian , Score: 0.9999889930023003
# Least Influencial Word: dna , Score: 0.3475982746535392
#
# Publisher:  Delhi Daily News
# business
# Most Influencial Word: tax , Score: 0.992432494243197
# Least Influencial Word: ocean , Score: 0.35271649719825815
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999891523805218
# Least Influencial Word: ocean , Score: 0.35271649719825815
#
# health
# Most Influencial Word: kardashian , Score: 0.9999891523805218
# Least Influencial Word: increas , Score: 0.3418700483739398
#
# science
# Most Influencial Word: kardashian , Score: 0.9999891523805218
# Least Influencial Word: increas , Score: 0.3418700483739398
#
# Publisher:  Entertainmentwise
# business
# Most Influencial Word: tax , Score: 0.9948760589498553
# Least Influencial Word: california , Score: 0.33096907475410814
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999858179524161
# Least Influencial Word: california , Score: 0.33096907475410814
#
# health
# Most Influencial Word: kardashian , Score: 0.9999858179524161
# Least Influencial Word: california , Score: 0.33096907475410814
#
# science
# Most Influencial Word: kardashian , Score: 0.9999858179524161
# Least Influencial Word: california , Score: 0.33096907475410814
#
# Publisher:  Examiner.com
# business
# Most Influencial Word: tax , Score: 0.9965224961891468
# Least Influencial Word: employe , Score: 0.31432450562859193
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999809142387435
# Least Influencial Word: employe , Score: 0.31432450562859193
#
# health
# Most Influencial Word: kardashian , Score: 0.9999809142387435
# Least Influencial Word: employe , Score: 0.31432450562859193
#
# science
# Most Influencial Word: kardashian , Score: 0.9999809142387435
# Least Influencial Word: employe , Score: 0.31432450562859193
#
# Publisher:  Firstpost
# business
# Most Influencial Word: tax , Score: 0.9976047255638558
# Least Influencial Word: champion , Score: 0.3245501146075155
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999729838077867
# Least Influencial Word: electron , Score: 0.3174573902104766
#
# health
# Most Influencial Word: kardashian , Score: 0.9999729838077867
# Least Influencial Word: ban , Score: 0.3052208814748812
#
# science
# Most Influencial Word: kardashian , Score: 0.9999729838077867
# Least Influencial Word: shop , Score: 0.3006166687478468
#
# Publisher:  Fox News
# business
# Most Influencial Word: tax , Score: 0.9983186010998982
# Least Influencial Word: hear , Score: 0.2892607442929326
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999599225969261
# Least Influencial Word: hear , Score: 0.2892607442929326
#
# health
# Most Influencial Word: kardashian , Score: 0.9999599225969261
# Least Influencial Word: hear , Score: 0.2892607442929326
#
# science
# Most Influencial Word: kardashian , Score: 0.9999599225969261
# Least Influencial Word: hear , Score: 0.2892607442929326
#
# Publisher:  Headlines \& Global News
# business
# Most Influencial Word: tax , Score: 0.9987916557045411
# Least Influencial Word: storag , Score: 0.27989267446361227
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999404678544275
# Least Influencial Word: storag , Score: 0.27989267446361227
#
# health
# Most Influencial Word: kardashian , Score: 0.9999404678544275
# Least Influencial Word: storag , Score: 0.27989267446361227
#
# science
# Most Influencial Word: googl , Score: 0.9999548362561073
# Least Influencial Word: storag , Score: 0.27989267446361227
#
# Publisher:  Huffington Post
# business
# Most Influencial Word: tax , Score: 0.999106995102913
# Least Influencial Word: recommend , Score: 0.28621403684197044
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9999114527986559
# Least Influencial Word: rest , Score: 0.280169577478224
#
# health
# Most Influencial Word: kardashian , Score: 0.9999114527986559
# Least Influencial Word: carbon , Score: 0.27929058896890724
#
# science
# Most Influencial Word: googl , Score: 0.9999619488126958
# Least Influencial Word: carbon , Score: 0.27929058896890724
#
# Publisher:  Medical Daily
# business
# Most Influencial Word: tax , Score: 0.9992969705357191
# Least Influencial Word: termin , Score: 0.28363399799316924
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9998681250813972
# Least Influencial Word: culprit , Score: 0.26005258496562356
#
# health
# Most Influencial Word: kardashian , Score: 0.9998681250813972
# Least Influencial Word: culprit , Score: 0.26005258496562356
#
# science
# Most Influencial Word: googl , Score: 0.9999679202752384
# Least Influencial Word: culprit , Score: 0.26005258496562356
#
# Publisher:  NASDAQ
# business
# Most Influencial Word: tax , Score: 0.9994177217149396
# Least Influencial Word: diner , Score: 0.27025795916475026
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9997966888294607
# Least Influencial Word: personnel , Score: 0.2567428047038038
#
# health
# Most Influencial Word: kardashian , Score: 0.9997966888294607
# Least Influencial Word: personnel , Score: 0.2567428047038038
#
# science
# Most Influencial Word: googl , Score: 0.9999727382327449
# Least Influencial Word: personnel , Score: 0.2567428047038038
#
# Publisher:  NDTV
# business
# Most Influencial Word: tax , Score: 0.9994931735260796
# Least Influencial Word: mourn , Score: 0.26708942736486135
#
# entertainment
# Most Influencial Word: kardashian , Score: 0.9996830858112176
# Least Influencial Word: headach , Score: 0.26444728738153445
#
# health
# Most Influencial Word: kardashian , Score: 0.9996830858112176
# Least Influencial Word: headach , Score: 0.26444728738153445
#
# science
# Most Influencial Word: googl , Score: 0.9999765143688558
# Least Influencial Word: resurg , Score: 0.2625999793935441
# Publisher:  Reuters
# business
# Most Influencial Word: tax , Score: 0.9995386917610881
# Least Influencial Word: mishap , Score: 0.2716221526084888
#
# entertainment
# Most Influencial Word: tax , Score: 0.9995386917610881
# Least Influencial Word: mishap , Score: 0.2716221526084888
#
# health
# Most Influencial Word: cancer , Score: 0.9996715663896173
# Least Influencial Word: subject , Score: 0.2704212266430162
#
# science
# Most Influencial Word: googl , Score: 0.9999797616793615
# Least Influencial Word: address , Score: 0.26486205495708404
#
# Publisher:  Science World Report
# business
# Most Influencial Word: tax , Score: 0.999564104570641
# Least Influencial Word: programm , Score: 0.2600775507858568
#
# entertainment
# Most Influencial Word: tax , Score: 0.999564104570641
# Least Influencial Word: programm , Score: 0.2600775507858568
#
# health
# Most Influencial Word: cancer , Score: 0.9996698968495609
# Least Influencial Word: programm , Score: 0.2600775507858568
#
# science
# Most Influencial Word: googl , Score: 0.9999825561431779
# Least Influencial Word: programm , Score: 0.2600775507858568
#
# Publisher:  Tech Times
# business
# Most Influencial Word: tax , Score: 0.999575654004961
# Least Influencial Word: nyc , Score: 0.28222504386297276
#
# entertainment
# Most Influencial Word: tax , Score: 0.999575654004961
# Least Influencial Word: nyc , Score: 0.28222504386297276
#
# health
# Most Influencial Word: cancer , Score: 0.9996556526091515
# Least Influencial Word: mastectomi , Score: 0.27826747199646173
#
# science
# Most Influencial Word: googl , Score: 0.9999849620725902
# Least Influencial Word: abort , Score: 0.2737163966566214
#
# Publisher:  Ubergizmo
# business
# Most Influencial Word: tax , Score: 0.9995772547819392
# Least Influencial Word: brown , Score: 0.28622779137128246
#
# entertainment
# Most Influencial Word: tax , Score: 0.9995772547819392
# Least Influencial Word: brown , Score: 0.28622779137128246
#
# health
# Most Influencial Word: cancer , Score: 0.9996310639543862
# Least Influencial Word: brown , Score: 0.28622779137128246
#
# science
# Most Influencial Word: appl , Score: 0.9999873171199473
# Least Influencial Word: brown , Score: 0.28622779137128246
